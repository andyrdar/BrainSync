# %% [markdown]
# ## Video Selection
#
# Choose DAD videoclips based on Valence and Arousal scores
#
# Created: Nov 18, 2025 <br>
# Last modified: Nov 20, 2025

# %%
# Imports
import pandas as pd
import itertools

# %%
# Load data and round scores for sorting
df = pd.read_csv(r'C:\Users\aruizdargence\Downloads\LIRIS-ACCEDE-annotations\LIRIS-ACCEDE-annotations\annotations/ACCEDEranking.txt', sep='\t')

df["valenceValue_rounded"] = df["valenceValue"].round(2)
df["arousalValue_rounded"] = df["arousalValue"].round(2)

df
# Out:
#         id             name  valenceRank  arousalRank  valenceValue  \
# 0        0  ACCEDE00000.mp4         3755          787      2.764340
# 1        1  ACCEDE00001.mp4         6711         6428      3.260093
# 2        2  ACCEDE00002.mp4         5043         3591      3.047528
# 3        3  ACCEDE00003.mp4         7584         5615      3.338461
# 4        4  ACCEDE00004.mp4         5014         4463      3.042496
# ...    ...              ...          ...          ...           ...
# 9795  9795  ACCEDE09795.mp4         8315         3236      3.406446
# 9796  9796  ACCEDE09796.mp4         9784         1775      3.591728
# 9797  9797  ACCEDE09797.mp4         9729         1560      3.583121
# 9798  9798  ACCEDE09798.mp4         9605          100      3.564251
# 9799  9799  ACCEDE09799.mp4         9180         1206      3.504964
#
#       arousalValue  valenceVariance  arousalVariance
# 0         1.366938         0.118453         0.148906
# 1         2.792376         0.104211         0.154526
# 2         1.840160         0.109841         0.149310
# 3         2.470821         0.100953         0.164621
# 4         2.082151         0.110000         0.163321
# ...            ...              ...              ...
# 9795      1.754529         0.101927         0.141201
# 9796      1.480602         0.163026         0.116369
# 9797      1.450951         0.158730         0.118500
# 9798      1.321943         0.149619         0.203450
# 9799      1.408089         0.124627         0.127924
#
# [9800 rows x 8 columns]

# %%
# create dictionary with 15 videos for each affect
affects = {
    "highV_highA" : [False, False],
    "highV_lowA" : [False, True],
    "lowV_highA" : [True, False],
    "lowV_lowA" : [True, True]
}

rows = []
minv = df.sort_values(by="valenceValue_rounded", ascending=True)[:200]
maxv = df.sort_values(by="valenceValue_rounded", ascending=False)[:200]

for label, (v_order, a_order) in affects.items():
    if v_order:
        subset = (minv.sort_values(by="arousalValue_rounded", ascending=a_order).head(90)[["name", "valenceValue_rounded", "arousalValue_rounded"]])

    else:
        subset = (maxv.sort_values(by="arousalValue_rounded", ascending=a_order).head(90)[["name", "valenceValue_rounded", "arousalValue_rounded"]])
    
    subset["path"] = "d:/optilab/synchrony/data/video"+ subset["name"]
    subset["name"] = subset["name"].str.replace(".mp4", "")
    subset ["affect"] = label

    rows.append(subset)

video_df = pd.concat(rows, ignore_index=True)
video_df
# Out:
#             name  valenceValue_rounded  arousalValue_rounded  \
# 0    ACCEDE06618                  3.59                  4.49
# 1    ACCEDE01212                  3.59                  4.36
# 2    ACCEDE06669                  3.58                  4.35
# 3    ACCEDE08857                  3.57                  4.28
# 4    ACCEDE01362                  3.57                  4.20
# ..           ...                   ...                   ...
# 355  ACCEDE07733                  1.38                  3.37
# 356  ACCEDE02581                  1.33                  3.37
# 357  ACCEDE01239                  1.36                  3.51
# 358  ACCEDE06205                  1.41                  3.53
# 359  ACCEDE07340                  1.37                  3.55
#
#                                                path       affect
# 0    d:/optilab/synchrony/data/videoACCEDE06618.mp4  highV_highA
# 1    d:/optilab/synchrony/data/videoACCEDE01212.mp4  highV_highA
# 2    d:/optilab/synchrony/data/videoACCEDE06669.mp4  highV_highA
# 3    d:/optilab/synchrony/data/videoACCEDE08857.mp4  highV_highA
# 4    d:/optilab/synchrony/data/videoACCEDE01362.mp4  highV_highA
# ..                                              ...          ...
# 355  d:/optilab/synchrony/data/videoACCEDE07733.mp4    lowV_lowA
# 356  d:/optilab/synchrony/data/videoACCEDE02581.mp4    lowV_lowA
# 357  d:/optilab/synchrony/data/videoACCEDE01239.mp4    lowV_lowA
# 358  d:/optilab/synchrony/data/videoACCEDE06205.mp4    lowV_lowA
# 359  d:/optilab/synchrony/data/videoACCEDE07340.mp4    lowV_lowA
#
# [360 rows x 5 columns]

# %%
pairs = []

for v1, v2 in itertools.combinations(video_df.itertuples(index=False), 2):
    if v1.path == v2.path and v1.affect == v2.affect:
        condition = "same_name_same_affect"

    elif v1.path != v2.path and v1.affect == v2.affect:
        condition = "same_affect_diff_name"

    elif v1.path != v2.path and v1.affect != v2.affect:
        condition = "diff_name_diff_affect"
    
    else:
        continue

    pairs.append({
        "v1_name" : v1.path,
        "v1_affect" : v1.affect,
        "v2_name" : v2.path,
        "v2_affect" : v2.affect,
        "condition" : condition
    })

pairs_df = pd.DataFrame(pairs)
pairs_df
# Out:
#                                               v1_name    v1_affect  \
# 0      d:/optilab/synchrony/data/videoACCEDE06618.mp4  highV_highA
# 1      d:/optilab/synchrony/data/videoACCEDE06618.mp4  highV_highA
# 2      d:/optilab/synchrony/data/videoACCEDE06618.mp4  highV_highA
# 3      d:/optilab/synchrony/data/videoACCEDE06618.mp4  highV_highA
# 4      d:/optilab/synchrony/data/videoACCEDE06618.mp4  highV_highA
# ...                                               ...          ...
# 64615  d:/optilab/synchrony/data/videoACCEDE02581.mp4    lowV_lowA
# 64616  d:/optilab/synchrony/data/videoACCEDE02581.mp4    lowV_lowA
# 64617  d:/optilab/synchrony/data/videoACCEDE01239.mp4    lowV_lowA
# 64618  d:/optilab/synchrony/data/videoACCEDE01239.mp4    lowV_lowA
# 64619  d:/optilab/synchrony/data/videoACCEDE06205.mp4    lowV_lowA
#
#                                               v2_name    v2_affect  \
# 0      d:/optilab/synchrony/data/videoACCEDE01212.mp4  highV_highA
# 1      d:/optilab/synchrony/data/videoACCEDE06669.mp4  highV_highA
# 2      d:/optilab/synchrony/data/videoACCEDE08857.mp4  highV_highA
# 3      d:/optilab/synchrony/data/videoACCEDE01362.mp4  highV_highA
# 4      d:/optilab/synchrony/data/videoACCEDE01210.mp4  highV_highA
# ...                                               ...          ...
# 64615  d:/optilab/synchrony/data/videoACCEDE06205.mp4    lowV_lowA
# 64616  d:/optilab/synchrony/data/videoACCEDE07340.mp4    lowV_lowA
# 64617  d:/optilab/synchrony/data/videoACCEDE06205.mp4    lowV_lowA
# 64618  d:/optilab/synchrony/data/videoACCEDE07340.mp4    lowV_lowA
# 64619  d:/optilab/synchrony/data/videoACCEDE07340.mp4    lowV_lowA
#
#                    condition
# 0      same_affect_diff_name
# 1      same_affect_diff_name
# 2      same_affect_diff_name
# 3      same_affect_diff_name
# 4      same_affect_diff_name
# ...                      ...
# 64615  same_affect_diff_name
# 64616  same_affect_diff_name
# 64617  same_affect_diff_name
# 64618  same_affect_diff_name
# 64619  same_affect_diff_name
#
# [64620 rows x 5 columns]

# %%
import pandas as pd

video1 = video_df
while True:
    video2 = video1.sample(frac=1).reset_index(drop=True)
    
    # ensure no video is paired with itself
    if not (video1["name"] == video2["name"]).any():
        break


pairs = pd.DataFrame({
    "video1_name": video1["path"],
    "video1_affect": video1["affect"],
    "video2_name": video2["path"],
    "video2_affect": video2["affect"]
})

# Add condition column
def get_condition(row):
    if row.video1_name == row.video2_name and row.video1_affect == row.video2_affect:
        return "same_name_same_affect"
    elif row.video1_affect == row.video2_affect and row.video1_name != row.video2_name:
        return "same_affect_diff_name"
    elif row.video1_affect != row.video2_affect:
        return "diff_affect_diff_name"
    else:
        return "other"

pairs["condition"] = pairs.apply(get_condition, axis=1)

# save to csv
pairs.to_csv(r'd:\optilab\synchrony\data/paired_videos.csv')

pairs
# Out:
#                                         video1_name video1_affect  \
# 0    d:/optilab/synchrony/data/videoACCEDE06618.mp4   highV_highA
# 1    d:/optilab/synchrony/data/videoACCEDE01212.mp4   highV_highA
# 2    d:/optilab/synchrony/data/videoACCEDE06669.mp4   highV_highA
# 3    d:/optilab/synchrony/data/videoACCEDE08857.mp4   highV_highA
# 4    d:/optilab/synchrony/data/videoACCEDE01362.mp4   highV_highA
# ..                                              ...           ...
# 355  d:/optilab/synchrony/data/videoACCEDE07733.mp4     lowV_lowA
# 356  d:/optilab/synchrony/data/videoACCEDE02581.mp4     lowV_lowA
# 357  d:/optilab/synchrony/data/videoACCEDE01239.mp4     lowV_lowA
# 358  d:/optilab/synchrony/data/videoACCEDE06205.mp4     lowV_lowA
# 359  d:/optilab/synchrony/data/videoACCEDE07340.mp4     lowV_lowA
#
#                                         video2_name video2_affect  \
# 0    d:/optilab/synchrony/data/videoACCEDE07128.mp4    highV_lowA
# 1    d:/optilab/synchrony/data/videoACCEDE06690.mp4     lowV_lowA
# 2    d:/optilab/synchrony/data/videoACCEDE06621.mp4    highV_lowA
# 3    d:/optilab/synchrony/data/videoACCEDE02922.mp4    lowV_highA
# 4    d:/optilab/synchrony/data/videoACCEDE07166.mp4     lowV_lowA
# ..                                              ...           ...
# 355  d:/optilab/synchrony/data/videoACCEDE04455.mp4   highV_highA
# 356  d:/optilab/synchrony/data/videoACCEDE00693.mp4   highV_highA
# 357  d:/optilab/synchrony/data/videoACCEDE01292.mp4    lowV_highA
# 358  d:/optilab/synchrony/data/videoACCEDE00354.mp4   highV_highA
# 359  d:/optilab/synchrony/data/videoACCEDE03822.mp4    highV_lowA
#
#                  condition
# 0    diff_affect_diff_name
# 1    diff_affect_diff_name
# 2    diff_affect_diff_name
# 3    diff_affect_diff_name
# 4    diff_affect_diff_name
# ..                     ...
# 355  diff_affect_diff_name
# 356  diff_affect_diff_name
# 357  diff_affect_diff_name
# 358  diff_affect_diff_name
# 359  diff_affect_diff_name
#
# [360 rows x 5 columns]
